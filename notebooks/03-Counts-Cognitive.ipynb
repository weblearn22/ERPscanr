# %% [markdown]
# # Counts Analysis with Cognitive Associations
#
# Co-occurence of terms analysis: check how often pre-selected cognitive terms appear in abstracts with ERP terms.
#
# This analysis searches through pubmed for papers that contain specified ERP and selected association terms.
#
# Data extracted is the count of the number of papers with both terms. This is used to infer the associated terms for each ERP.
#
# This notebook covers the cognitive association terms.

# %%
# %matplotlib inline

import numpy as np
from scipy.stats import normaltest

from lisc import Counts
from lisc.utils import SCDB, load_object
from lisc.plts.counts import plot_matrix, plot_clustermap, plot_dendrogram

# %%
# Import custom project code
import sys
sys.path.append('../code')
from plts import plot_count_hist, plot_time_associations
from analysis import get_time_associations

# %% [markdown]
# ## Setup

# %%
# Settings
SAVE_FIG = False

# %%
# Set the file locations
term_dir = '../terms/'
figs_dir = '../data/figures/counts'
db = SCDB('../data/')

# %%
# Set the name of the file to load
name = 'cognitive'

# %%
# Load the counts object
counts = load_object('counts_' + name, directory=db)

# %% [markdown]
# ### Check Database Information
#
# Check the metadata about the data collection, including checking the database data were collected from.

# %%
# Check database information
counts.meta_data.db_info
# Out:
# {'dbname': 'pubmed',
#  'menuname': 'PubMed',
#  'description': 'PubMed bibliographic record',
#  'dbbuild': 'Build210226-2212m.3',
#  'count': '32200710',
#  'lastupdate': '2021/02/27 15:01'}

# %%
# Check requester details
counts.meta_data.requester
# Out:
# {'n_requests': 8009,
#  'wait_time': 0.1,
#  'start_time': '10:15:11 Sunday 28 February 2021',
#  'end_time': '10:59:20 Sunday 28 February 2021',
#  'logging': None}

# %% [markdown]
# # Global Summaries

# %%
# Check the distribution of ERP papers
print('The total # of ERP papers is \t\t {:.0f}'.format(sum(counts.terms['A'].counts)))
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['A'].counts))))
plot_count_hist(counts.terms['A'].counts, 
                save_fig=SAVE_FIG, f_name='erp_hist.pdf', directory=figs_dir)
# Out:
# The total # of ERP papers is 		 31772
# Test for normality (log-spaced) 	 t-val: 7.25 	 p-val 0.03

# %%
# Check the distribution of ERP papers
print('The total # of association papers is \t\t {:.0f}'.format(sum(counts.terms['B'].counts)))
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['B'].counts))))
plot_count_hist(counts.terms['B'].counts,
                save_fig=SAVE_FIG, f_name=name + '_assoc_hist.pdf', directory=figs_dir)
# Out:
# The total # of association papers is 		 8903115
# Test for normality (log-spaced) 	 t-val: 7.92 	 p-val 0.02

# %% [markdown]
# # Check Counts

# %%
# Check the terms with the most papers
counts.check_top(dim='A')
counts.check_top(dim='B')
# Out:
# The most studied term is  'P300'  with  6110  articles.
# The most studied term is  'intelligence'  with  785384  articles.

# %%
# Check how many papers were found for each ERP term
counts.check_counts(dim='A')
# Out:
# The number of documents found for each search term is:
#   'P100'    -   1822
#   'P150'    -    217
#   'P170'    -     39
#   'P180'    -     92
#   'P200'    -    843
#   'P220'    -     50
#   'P230'    -     27
#   'P240'    -     31
#   'P250'    -     97
#   'P270'    -     17
#   'P300'    -   6110
#   'P3a'     -   1007
#   'P3b'     -   1054
#   'P340'    -     10
#   'P350'    -     72
#   'P400'    -    180
#   'P500'    -     66
#   'P550'    -     16
#   'P600'    -    708
#   'N100'    -   1021
#   'N110'    -     22
#   'N120'    -     56
#   'N130'    -     40
#   'N140'    -    176
#   'N150'    -    120
#   'N160'    -     64
#   'N170'    -   1357
#   'N180'    -     38
#   'N190'    -     23
#   'N200'    -    769
#   'N2a'     -    174
#   'N2b'     -    233
#   'N2c'     -     35
#   'N2pc'    -    497
#   'N240'    -     19
#   'N250'    -    265
#   'N270'    -     66
#   'N280'    -     23
#   'N290'    -     51
#   'N300'    -    195
#   'N320'    -     25
#   'N350'    -     83
#   'N400'    -   2555
#   'N450'    -    177
#   'N550'    -     52
#   'N600'    -     16
#   'N700'    -     18
#   'MMN'     -   3700
#   'LPC'     -    641
#   'LPP'     -    924
#   'NSW'     -    102
#   'PSW'     -    111
#   'VPP'     -     57
#   'CNV'     -   1004
#   'PINV'    -     32
#   'ELAN'    -     33
#   'LAN'     -     54
#   'CPS'     -     37
#   'LRP'     -    300
#   'LDN'     -     35
#   'ORN'     -     37
#   'BP'      -    521
#   'ERN'     -   1017
#   'Pe'      -    301
#   'CRN'     -     92
#   'MFN'     -     94
#   'SPeN'    -    122
#   'FRN'     -    574
#   'Pd'      -     22
#   'EDAN'    -     22
#   'LDAP'    -     15
#   'ADAN'    -     29
#   'EPN'     -    235
#   'SN'      -     76
#   'SP'      -     33
#   'SPN'     -     19
#   'SPCN'    -     41
#   'PCN'     -     62
#   'VsEP'    -    193
#   'MRPC'    -    297
#   'FSP'     -     20
#   'pN'      -     23
#   'LPN'     -     28
#   'LPP'     -     23
#   'EFN'     -     10
#   'FN400'   -    165
#   'PMN'     -     12
#   'VAN'     -     31

# %%
# Check how many papers were found for each association term
counts.check_counts(dim='B')
# Out:
# The number of documents found for each search term is:
#   'anticipation'         -   373676
#   'attention'            -   446655
#   'arousal'              -    29215
#   'auditory'             -   105329
#   'awareness'            -   159131
#   'categorization'       -    16704
#   'cognitive control'    -     7778
#   'comprehension'        -    25676
#   'conflict'             -    54771
#   'conscious'            -    81772
#   'decision making'      -   148983
#   'emotion'              -   254820
#   'error'                -   208881
#   'executive function'   -    23979
#   'expectation'          -    28176
#   'face'                 -   311553
#   'fear'                 -    68619
#   'goal'                 -   261167
#   'illusion'             -    10119
#   'intelligence'         -   785384
#   'language'             -   158177
#   'learning'             -   334770
#   'memory'               -   263732
#   'motor'                -   705891
#   'music'                -    20915
#   'pain'                 -   659788
#   'perception'           -   182288
#   'phonology'            -    15696
#   'prediction'           -   562546
#   'reading'              -   128178
#   'reasoning'            -    23895
#   'recognition'          -   378356
#   'representation'       -    86162
#   'reward'               -    71244
#   'semantic'             -    35030
#   'sleep'                -   174844
#   'spatial'              -   339061
#   'speech'               -    93158
#   'social'               -   565876
#   'somatosensory'        -    46730
#   'syntax'               -    12029
#   'unconscious'          -    10204
#   'valence'              -    83366
#   'vision'               -   515243
#   'working memory'       -    33548

# %%
# Check the most commonly associated association term for each ERP
counts.check_data()
# Out:
# For  'P100'   the highest association is  'vision'              with        1211
# For  'P150'   the highest association is  'vision'              with          41
# For  'P170'   the highest association is  'vision'              with           9
# For  'P180'   the highest association is  'motor'               with          17
# For  'P200'   the highest association is  'auditory'            with         288
# For  'P220'   the highest association is  'vision'              with           9
# For  'P230'   the highest association is  'vision'              with           9
# For  'P240'   the highest association is  'somatosensory'       with          10
# For  'P250'   the highest association is  'vision'              with          25
# For  'P270'   the highest association is  'vision'              with           8
# For  'P300'   the highest association is  'auditory'            with        1873
# For  'P3a'    the highest association is  'attention'           with         492
# For  'P3b'    the highest association is  'attention'           with         447
# For  'P340'   the highest association is  'somatosensory'       with           4
# For  'P350'   the highest association is  'auditory'            with          18
# For  'P400'   the highest association is  'face'                with          45
# For  'P500'   the highest association is  'vision'              with          12
# For  'P550'   the highest association is  'semantic'            with           4
# For  'P600'   the highest association is  'syntax'              with         320
# For  'N100'   the highest association is  'auditory'            with         602
# For  'N110'   the highest association is  'somatosensory'       with           6
# For  'N120'   the highest association is  'vision'              with          16
# For  'N130'   the highest association is  'vision'              with          14
# For  'N140'   the highest association is  'somatosensory'       with         128
# For  'N150'   the highest association is  'vision'              with          47
# For  'N160'   the highest association is  'vision'              with          35
# For  'N170'   the highest association is  'face'                with        1056
# For  'N180'   the highest association is  'vision'              with          23
# For  'N190'   the highest association is  'vision'              with          12
# For  'N200'   the highest association is  'auditory'            with         214
# For  'N2a'    the highest association is  'motor'               with          15
# For  'N2b'    the highest association is  'auditory'            with         107
# For  'N2c'    the highest association is  'attention'           with          11
# For  'N2pc'   the highest association is  'attention'           with         443
# For  'N240'   the highest association is  'somatosensory'       with           9
# For  'N250'   the highest association is  'recognition'         with         120
# For  'N270'   the highest association is  'vision'              with          34
# For  'N280'   the highest association is  'semantic'            with           5
# For  'N290'   the highest association is  'face'                with          38
# For  'N300'   the highest association is  'vision'              with          48
# For  'N320'   the highest association is  'reading'             with           8
# For  'N350'   the highest association is  'sleep'               with          36
# For  'N400'   the highest association is  'semantic'            with        1500
# For  'N450'   the highest association is  'conflict'            with          83
# For  'N550'   the highest association is  'sleep'               with          38
# For  'N600'   the highest association is  'emotion'             with           6
# For  'N700'   the highest association is  'vision'              with          10
# For  'MMN'    the highest association is  'auditory'            with        2172
# For  'LPC'    the highest association is  'memory'              with         171
# For  'LPP'    the highest association is  'emotion'             with         630
# For  'NSW'    the highest association is  'memory'              with          41
# For  'PSW'    the highest association is  'memory'              with          45
# For  'VPP'    the highest association is  'face'                with          47
# For  'CNV'    the highest association is  'motor'               with         303
# For  'PINV'   the highest association is  'auditory'            with           6
# For  'ELAN'   the highest association is  'syntax'              with          28
# For  'LAN'    the highest association is  'syntax'              with          29
# For  'CPS'    the highest association is  'speech'              with          28
# For  'LRP'    the highest association is  'motor'               with         185
# For  'LDN'    the highest association is  'auditory'            with          26
# For  'ORN'    the highest association is  'auditory'            with          34
# For  'BP'     the highest association is  'motor'               with         419
# For  'ERN'    the highest association is  'error'               with        1017
# For  'Pe'     the highest association is  'error'               with         301
# For  'CRN'    the highest association is  'error'               with          84
# For  'MFN'    the highest association is  'social'              with          28
# For  'SPeN'   the highest association is  'anticipation'        with          86
# For  'FRN'    the highest association is  'reward'              with         280
# For  'Pd'     the highest association is  'attention'           with          21
# For  'EDAN'   the highest association is  'attention'           with          22
# For  'LDAP'   the highest association is  'attention'           with          15
# For  'ADAN'   the highest association is  'attention'           with          29
# For  'EPN'    the highest association is  'emotion'             with         185
# For  'SN'     the highest association is  'attention'           with          64
# For  'SP'     the highest association is  'attention'           with          30
# For  'SPN'    the highest association is  'vision'              with          16
# For  'SPCN'   the highest association is  'vision'              with          36
# For  'PCN'    the highest association is  'vision'              with          54
# For  'VsEP'   the highest association is  'auditory'            with          62
# For  'MRPC'   the highest association is  'motor'               with         297
# For  'FSP'    the highest association is  'attention'           with          18
# For  'pN'     the highest association is  'motor'               with          17
# For  'LPN'    the highest association is  'memory'              with          20
# For  'LPP'    the highest association is  'language'            with          10
# For  'EFN'    the highest association is  'auditory'            with           4
# For  'FN400'  the highest association is  'recognition'         with         148
# For  'PMN'    the highest association is  'phonology'           with          12
# For  'VAN'    the highest association is  'awareness'           with          31

# %%
# Check the most commonly associated ERP for each term
counts.check_data(dim='B')
# Out:
# For  'anticipation'        the highest association is  'CNV'    with         269
# For  'attention'           the highest association is  'P300'   with        1343
# For  'arousal'             the highest association is  'P300'   with         143
# For  'auditory'            the highest association is  'MMN'    with        2172
# For  'awareness'           the highest association is  'P300'   with          89
# For  'categorization'      the highest association is  'N170'   with          96
# For  'cognitive control'   the highest association is  'ERN'    with         153
# For  'comprehension'       the highest association is  'N400'   with         557
# For  'conflict'            the highest association is  'ERN'    with         134
# For  'conscious'           the highest association is  'P300'   with         173
# For  'decision making'     the highest association is  'FRN'    with         143
# For  'emotion'             the highest association is  'LPP'    with         630
# For  'error'               the highest association is  'ERN'    with        1017
# For  'executive function'  the highest association is  'P300'   with          92
# For  'expectation'         the highest association is  'N400'   with          47
# For  'face'                the highest association is  'N170'   with        1056
# For  'fear'                the highest association is  'N170'   with          75
# For  'goal'                the highest association is  'P300'   with         122
# For  'illusion'            the highest association is  'MMN'    with          27
# For  'intelligence'        the highest association is  'P300'   with         247
# For  'language'            the highest association is  'N400'   with         855
# For  'learning'            the highest association is  'P300'   with         278
# For  'memory'              the highest association is  'P300'   with         725
# For  'motor'               the highest association is  'P300'   with         568
# For  'music'               the highest association is  'MMN'    with         193
# For  'pain'                the highest association is  'P300'   with          83
# For  'perception'          the highest association is  'MMN'    with         477
# For  'phonology'           the highest association is  'MMN'    with         252
# For  'prediction'          the highest association is  'MMN'    with         313
# For  'reading'             the highest association is  'N400'   with         825
# For  'reasoning'           the highest association is  'N400'   with          26
# For  'recognition'         the highest association is  'N400'   with         477
# For  'representation'      the highest association is  'MMN'    with         193
# For  'reward'              the highest association is  'FRN'    with         280
# For  'semantic'            the highest association is  'N400'   with        1500
# For  'sleep'               the highest association is  'P300'   with         137
# For  'spatial'             the highest association is  'P300'   with         344
# For  'speech'              the highest association is  'MMN'    with         581
# For  'social'              the highest association is  'N170'   with         243
# For  'somatosensory'       the highest association is  'P300'   with         214
# For  'syntax'              the highest association is  'P600'   with         320
# For  'unconscious'         the highest association is  'N400'   with          24
# For  'valence'             the highest association is  'LPP'    with         335
# For  'vision'              the highest association is  'P300'   with        1370
# For  'working memory'      the highest association is  'P300'   with         245

# %% [markdown]
# ## Select ERPs with enough articles

# %%
# Check how many ERPs currently
counts.terms['A'].n_terms
# Out:
# 88

# %%
# Drop ERPs without a target number of articles
counts.drop_data(100, dim='A')
print(counts.terms['A'].n_terms)
# Out:
# 36

# %% [markdown]
# ## Group Level Plots

# %%
# Compute the normalized score (percent association)
counts.compute_score('normalize', dim='A')

# %%
# Plot the matrix of percent associations - ERPs & terms
plot_matrix(counts, figsize=(10, 8), 
            save_fig=SAVE_FIG, f_name=name+'_associations.pdf', directory=figs_dir)

# %%
# Plot a clustermap, clustering ERPs and terms based on similarity
plot_clustermap(counts, attribute='score', cmap='blue', figsize=(12, 10),
                save_fig=SAVE_FIG, f_name=name+'_similarity_cluster.pdf', directory=figs_dir)

# %% [markdown]
# ### Similarity Measure

# %%
# Calculate similarity between all ERPs (based on term association percents)
counts.compute_score('similarity', 'A')

# %%
# Plot similarity matrix between ERPs
plot_matrix(counts, figsize=(10, 7),
            save_fig=SAVE_FIG, f_name=name+'_similarity.pdf', directory=figs_dir)

# %%
# Plot a clustermap, clustering ERPs and terms based on similarity
plot_clustermap(counts, attribute='score', cmap='blue', figsize=(12, 10),
                save_fig=SAVE_FIG, f_name=name+'_similarity_cluster.pdf', directory=figs_dir)

# %% [markdown]
# ### Association Score

# %%
# Calculate association between all ERPs
counts.compute_score('association')

# %%
# Plot similarity matrix between terms
plot_matrix(counts, figsize=(10, 7),
            save_fig=SAVE_FIG, f_name=name+'_associations.pdf', directory=figs_dir)

# %% [markdown]
# ### Dendrograms

# %%
# Plot dendrogram of ERPs, based on percent associations with terms
plot_dendrogram(counts, attribute='score', figsize=(6, 8),
                save_fig=SAVE_FIG, f_name=name+'_erp_dendro.pdf', directory=figs_dir)

# %%
# Plot dendrogram of termss, based on percent associations with ERPs
plot_dendrogram(counts, attribute='score', transpose=True, figsize=(6, 8),
                save_fig=SAVE_FIG, f_name=name+'term_dendro.pdf', directory=figs_dir)

# %% [markdown]
# ### Function correlates across time

# %%
# Re-compute normalized score
counts.compute_score('normalize')

# %%
# Get the time and polarity information for the ERPs
time_associations = get_time_associations(counts)

# %%
# Plot time associations
plot_time_associations(time_associations,
                       save_fig=SAVE_FIG, f_name=name+'time.pdf', directory=figs_dir)
