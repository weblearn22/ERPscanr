# %% [markdown]
# # Counts Analysis with other ERP associations
#
# Co-occurence of terms analysis: check how often pre-selected cognitive terms appear in abstracts with ERP terms.
#
# This analysis searches through pubmed for papers that contain specified ERP and selected association terms.
#
# Data extracted is the count of the number of papers with both terms. This is used to infer the associated terms for each ERP.
#
# This notebook covers the associations with other ERP component terms.

# %%
# %matplotlib inline

import numpy as np
from scipy.stats import normaltest

from lisc import Counts
from lisc.utils import SCDB, load_object
from lisc.plts.counts import plot_matrix, plot_clustermap, plot_dendrogram

# %%
# Import custom project code
import sys
sys.path.append('../code')
from plts import plot_count_hist, plot_time_associations
from analysis import get_time_associations

# %% [markdown]
# ## Setup

# %%
# Settings
SAVE_FIG = False

# %%
# Set the file locations
term_dir = '../terms/'
figs_dir = '../data/figures/counts'
db = SCDB('../data/')

# %%
# Set the name of the file to load
name = 'erp'

# %%
# Load the counts object
counts = load_object('counts_' + name, directory=db)

# %% [markdown]
# ### Check Database Information
#
# Check the metadata about the data collection, including checking the database data were collected from.

# %%
# Check database information
counts.meta_data.db_info
# Out:
# {'dbname': 'pubmed',
#  'menuname': 'PubMed',
#  'description': 'PubMed bibliographic record',
#  'dbbuild': 'Build210226-2212m.3',
#  'count': '32200710',
#  'lastupdate': '2021/02/27 15:01'}

# %%
# Check requester details
counts.meta_data.requester
# Out:
# {'n_requests': 3917,
#  'wait_time': 0.1,
#  'start_time': '12:07:38 Sunday 28 February 2021',
#  'end_time': '12:25:52 Sunday 28 February 2021',
#  'logging': None}

# %% [markdown]
# # Global Summaries

# %%
# Check the distribution of ERP papers
print('The total # of ERP papers is \t\t {:.0f}'.format(sum(counts.terms['A'].counts)))
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['A'].counts))))
plot_count_hist(counts.terms['A'].counts, 
                save_fig=SAVE_FIG, file_name='erp_hist.pdf', directory=figs_dir)
# Out:
# The total # of ERP papers is 		 31772
# Test for normality (log-spaced) 	 t-val: 7.25 	 p-val 0.03

# %% [markdown]
# # Check Counts

# %%
# Check the terms with the most papers
counts.check_top(dim='A')
# Out:
# The most studied term is  'P300'  with  6110  articles.

# %%
# Check how many papers were found for each ERP term
counts.check_counts(dim='A')
# Out:
# The number of documents found for each search term is:
#   'P100'    -   1822
#   'P150'    -    217
#   'P170'    -     39
#   'P180'    -     92
#   'P200'    -    843
#   'P220'    -     50
#   'P230'    -     27
#   'P240'    -     31
#   'P250'    -     97
#   'P270'    -     17
#   'P300'    -   6110
#   'P3a'     -   1007
#   'P3b'     -   1054
#   'P340'    -     10
#   'P350'    -     72
#   'P400'    -    180
#   'P500'    -     66
#   'P550'    -     16
#   'P600'    -    708
#   'N100'    -   1021
#   'N110'    -     22
#   'N120'    -     56
#   'N130'    -     40
#   'N140'    -    176
#   'N150'    -    120
#   'N160'    -     64
#   'N170'    -   1357
#   'N180'    -     38
#   'N190'    -     23
#   'N200'    -    769
#   'N2a'     -    174
#   'N2b'     -    233
#   'N2c'     -     35
#   'N2pc'    -    497
#   'N240'    -     19
#   'N250'    -    265
#   'N270'    -     66
#   'N280'    -     23
#   'N290'    -     51
#   'N300'    -    195
#   'N320'    -     25
#   'N350'    -     83
#   'N400'    -   2555
#   'N450'    -    177
#   'N550'    -     52
#   'N600'    -     16
#   'N700'    -     18
#   'MMN'     -   3700
#   'LPC'     -    641
#   'LPP'     -    924
#   'NSW'     -    102
#   'PSW'     -    111
#   'VPP'     -     57
#   'CNV'     -   1004
#   'PINV'    -     32
#   'ELAN'    -     33
#   'LAN'     -     54
#   'CPS'     -     37
#   'LRP'     -    300
#   'LDN'     -     35
#   'ORN'     -     37
#   'BP'      -    521
#   'ERN'     -   1017
#   'Pe'      -    301
#   'CRN'     -     92
#   'MFN'     -     94
#   'SPeN'    -    122
#   'FRN'     -    574
#   'Pd'      -     22
#   'EDAN'    -     22
#   'LDAP'    -     15
#   'ADAN'    -     29
#   'EPN'     -    235
#   'SN'      -     76
#   'SP'      -     33
#   'SPN'     -     19
#   'SPCN'    -     41
#   'PCN'     -     62
#   'VsEP'    -    193
#   'MRPC'    -    297
#   'FSP'     -     20
#   'pN'      -     23
#   'LPN'     -     28
#   'LPP'     -     23
#   'EFN'     -     10
#   'FN400'   -    165
#   'PMN'     -     12
#   'VAN'     -     31

# %%
# Check the most commonly associated association term for each ERP
counts.check_data()
# Out:
# For  'P100'   the highest association is  'N170'   with         143
# For  'P150'   the highest association is  'N250'   with          17
# For  'P170'   the highest association is  'N170'   with           5
# For  'P180'   the highest association is  'N100'   with          19
# For  'P200'   the highest association is  'N100'   with         314
# For  'P220'   the highest association is  'N150'   with           8
# For  'P230'   the highest association is  'N180'   with           7
# For  'P240'   the highest association is  'N150'   with           6
# For  'P250'   the highest association is  'N170'   with          17
# For  'P270'   the highest association is  'P100'   with           2
# For  'P300'   the highest association is  'N200'   with         411
# For  'P3a'    the highest association is  'P3b'    with         433
# For  'P3b'    the highest association is  'P3a'    with         433
# For  'P340'   the highest association is  'P400'   with           3
# For  'P350'   the highest association is  'P250'   with          11
# For  'P400'   the highest association is  'N290'   with          28
# For  'P500'   the highest association is  'P200'   with           6
# For  'P550'   the highest association is  'LPC'    with           4
# For  'P600'   the highest association is  'N400'   with         389
# For  'N100'   the highest association is  'P300'   with         348
# For  'N110'   the highest association is  'P300'   with           4
# For  'N120'   the highest association is  'P200'   with          12
# For  'N130'   the highest association is  'P300'   with           4
# For  'N140'   the highest association is  'P100'   with          72
# For  'N150'   the highest association is  'P100'   with          20
# For  'N160'   the highest association is  'P100'   with          11
# For  'N170'   the highest association is  'P100'   with         143
# For  'N180'   the highest association is  'P230'   with           7
# For  'N190'   the highest association is  'P100'   with           3
# For  'N200'   the highest association is  'P300'   with         411
# For  'N2a'    the highest association is  'N2b'    with          22
# For  'N2b'    the highest association is  'MMN'    with          68
# For  'N2c'    the highest association is  'P3b'    with           7
# For  'N2pc'   the highest association is  'PCN'    with          26
# For  'N240'   the highest association is  'P200'   with           5
# For  'N250'   the highest association is  'N170'   with          95
# For  'N270'   the highest association is  'N400'   with          13
# For  'N280'   the highest association is  'N400'   with           6
# For  'N290'   the highest association is  'P400'   with          28
# For  'N300'   the highest association is  'N400'   with          59
# For  'N320'   the highest association is  'N170'   with           4
# For  'N350'   the highest association is  'N550'   with          17
# For  'N400'   the highest association is  'P600'   with         389
# For  'N450'   the highest association is  'N400'   with          11
# For  'N550'   the highest association is  'N350'   with          17
# For  'N600'   the highest association is  'P300'   with           3
# For  'N700'   the highest association is  'N400'   with           6
# For  'MMN'    the highest association is  'P3a'    with         300
# For  'LPC'    the highest association is  'N400'   with         171
# For  'LPP'    the highest association is  'EPN'    with         120
# For  'NSW'    the highest association is  'P300'   with          19
# For  'PSW'    the highest association is  'P300'   with          22
# For  'VPP'    the highest association is  'N170'   with          36
# For  'CNV'    the highest association is  'P300'   with          90
# For  'PINV'   the highest association is  'CNV'    with          27
# For  'ELAN'   the highest association is  'P600'   with          16
# For  'LAN'    the highest association is  'P600'   with          30
# For  'CPS'    the highest association is  'P600'   with           4
# For  'LRP'    the highest association is  'P300'   with          27
# For  'LDN'    the highest association is  'MMN'    with          32
# For  'ORN'    the highest association is  'P400'   with           8
# For  'BP'     the highest association is  'MRPC'   with          57
# For  'ERN'    the highest association is  'Pe'     with         257
# For  'Pe'     the highest association is  'ERN'    with         257
# For  'CRN'    the highest association is  'ERN'    with          75
# For  'MFN'    the highest association is  'ERN'    with          13
# For  'SPeN'   the highest association is  'FRN'    with          21
# For  'FRN'    the highest association is  'P300'   with         138
# For  'Pd'     the highest association is  'N2pc'   with          16
# For  'EDAN'   the highest association is  'ADAN'   with          15
# For  'LDAP'   the highest association is  'ADAN'   with           8
# For  'ADAN'   the highest association is  'EDAN'   with          15
# For  'EPN'    the highest association is  'LPP'    with         120
# For  'SN'     the highest association is  'SP'     with          20
# For  'SP'     the highest association is  'SN'     with          20
# For  'SPN'    the highest association is  'LPP'    with           1
# For  'SPCN'   the highest association is  'PCN'    with          41
# For  'PCN'    the highest association is  'SPCN'   with          41
# For  'VsEP'   the highest association is  'LPP'    with           2
# For  'MRPC'   the highest association is  'BP'     with          57
# For  'FSP'    the highest association is  'SP'     with          20
# For  'pN'     the highest association is  'BP'     with          13
# For  'LPN'    the highest association is  'FN400'  with           6
# For  'LPP'    the highest association is  'P600'   with          12
# For  'EFN'    the highest association is  'N400'   with           3
# For  'FN400'  the highest association is  'LPC'    with          34
# For  'PMN'    the highest association is  'N400'   with          11
# For  'VAN'    the highest association is  'P300'   with           3

# %% [markdown]
# ## Select ERPs with enough articles

# %%
# Check how many ERPs currently
counts.terms['A'].n_terms
# Out:
# 88

# %%
# Drop ERPs without a target number of articles
counts.drop_data(150, dim='A')
print(counts.terms['A'].n_terms)
# Out:
# 32

# %% [markdown]
# ## Group Level Plots

# %%
# Compute the normalized score (percent association)
counts.compute_score('normalize', dim='A')

# %%
# Plot the matrix of percent associations - ERPs & terms
plot_matrix(counts, figsize=(10, 7.5),
            save_fig=SAVE_FIG, file_name=name+'_associations.pdf', directory=figs_dir)

# %% [markdown]
# ### Similarity Measure

# %%
# Calculate similarity between all ERPs (based on term association percents)
counts.compute_score('similarity')

# %%
# Plot similarity matrix between ERPs
plot_matrix(counts, figsize=(10, 6),
            save_fig=SAVE_FIG, file_name=name+'_similarity.pdf', directory=figs_dir)

# %%
# Plot a clustermap, clustering ERPs and terms based on similarity
plot_clustermap(counts, cmap='blue', figsize=(12, 10),
                save_fig=SAVE_FIG, file_name=name+'_similarity_cluster.pdf', directory=figs_dir)

# %% [markdown]
# ### Association Score

# %%
# Calculate association between all ERPs
counts.compute_score('association')

# %%
# Plot similarity matrix between terms
plot_matrix(counts, figsize=(10, 7),
            save_fig=SAVE_FIG, file_name=name+'_associations.pdf', directory=figs_dir)

# %% [markdown]
# ### Dendrograms

# %%
# Plot dendrogram of ERPs, based on percent associations with terms
plot_dendrogram(counts, attribute='counts', figsize=(6, 8),
                save_fig=SAVE_FIG, file_name=name+'_erp_dendro.pdf', directory=figs_dir)
# Out:
# /Users/tom/opt/anaconda3/lib/python3.8/site-packages/lisc/plts/counts.py:156: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_data = hier.linkage(data, method=method, metric=metric)
