# %% [markdown]
# # Counts Analysis with Disease Associations
#
# Co-occurence of terms analysis: check how often pre-selected cognitive terms appear in abstracts with ERP terms.
#
# This analysis searches through pubmed for papers that contain specified ERP and selected association terms.
#
# Data extracted is the count of the number of papers with both terms. This is used to infer the associated terms for each ERP.
#
# This notebook covers the disease association terms.

# %%
# %matplotlib inline

import numpy as np
from scipy.stats import normaltest

from lisc import Counts
from lisc.utils import SCDB, load_object
from lisc.plts.counts import plot_matrix, plot_clustermap, plot_dendrogram

# %%
# Import custom project code
import sys
sys.path.append('../code')
from plts import plot_count_hist, plot_time_associations
from analysis import get_time_associations

# %% [markdown]
# ## Setup

# %%
# Settings
SAVE_FIG = False

# %%
# Set the file locations
term_dir = '../terms/'
figs_dir = '../data/figures/counts'
db = SCDB('../data/')

# %%
# Set the name of the file to load
name = 'disease'

# %%
# Load the counts object
counts = load_object('counts_' + name, directory=db)

# %% [markdown]
# ### Check Database Information
#
# Check the metadata about the data collection, including checking the database data were collected from.

# %%
# Check database information
counts.meta_data.db_info
# Out:
# {'dbname': 'pubmed',
#  'menuname': 'PubMed',
#  'description': 'PubMed bibliographic record',
#  'dbbuild': 'Build210226-2212m.3',
#  'count': '32200710',
#  'lastupdate': '2021/02/27 15:01'}

# %%
# Check requester details
counts.meta_data.requester
# Out:
# {'n_requests': 4489,
#  'wait_time': 0.1,
#  'start_time': '11:31:30 Sunday 28 February 2021',
#  'end_time': '11:51:50 Sunday 28 February 2021',
#  'logging': None}

# %% [markdown]
# # Global Summaries

# %%
# Check the distribution of ERP papers
print('The total # of ERP papers is \t\t {:.0f}'.format(sum(counts.terms['A'].counts)))
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['A'].counts))))
plot_count_hist(counts.terms['A'].counts, 
                save_fig=SAVE_FIG, f_name='erp_hist.pdf', directory=figs_dir)
# Out:
# The total # of ERP papers is 		 31772
# Test for normality (log-spaced) 	 t-val: 7.25 	 p-val 0.03

# %%
# Check the distribution of ERP papers
print('The total # of association papers is \t\t {:.0f}'.format(sum(counts.terms['B'].counts)))
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['B'].counts))))
plot_count_hist(counts.terms['B'].counts,
                save_fig=SAVE_FIG, f_name=name + '_assoc_hist.pdf', directory=figs_dir)
# Out:
# The total # of association papers is 		 2103862
# Test for normality (log-spaced) 	 t-val: 0.08 	 p-val 0.96

# %% [markdown]
# # Check Counts

# %%
# Check the terms with the most papers
counts.check_top(dim='A')
counts.check_top(dim='B')
# Out:
# The most studied term is  'P300'  with  6110  articles.
# The most studied term is  'depression'  with  363681  articles.

# %%
# Check how many papers were found for each ERP term
counts.check_counts(dim='A')
# Out:
# The number of documents found for each search term is:
#   'P100'    -   1822
#   'P150'    -    217
#   'P170'    -     39
#   'P180'    -     92
#   'P200'    -    843
#   'P220'    -     50
#   'P230'    -     27
#   'P240'    -     31
#   'P250'    -     97
#   'P270'    -     17
#   'P300'    -   6110
#   'P3a'     -   1007
#   'P3b'     -   1054
#   'P340'    -     10
#   'P350'    -     72
#   'P400'    -    180
#   'P500'    -     66
#   'P550'    -     16
#   'P600'    -    708
#   'N100'    -   1021
#   'N110'    -     22
#   'N120'    -     56
#   'N130'    -     40
#   'N140'    -    176
#   'N150'    -    120
#   'N160'    -     64
#   'N170'    -   1357
#   'N180'    -     38
#   'N190'    -     23
#   'N200'    -    769
#   'N2a'     -    174
#   'N2b'     -    233
#   'N2c'     -     35
#   'N2pc'    -    497
#   'N240'    -     19
#   'N250'    -    265
#   'N270'    -     66
#   'N280'    -     23
#   'N290'    -     51
#   'N300'    -    195
#   'N320'    -     25
#   'N350'    -     83
#   'N400'    -   2555
#   'N450'    -    177
#   'N550'    -     52
#   'N600'    -     16
#   'N700'    -     18
#   'MMN'     -   3700
#   'LPC'     -    641
#   'LPP'     -    924
#   'NSW'     -    102
#   'PSW'     -    111
#   'VPP'     -     57
#   'CNV'     -   1004
#   'PINV'    -     32
#   'ELAN'    -     33
#   'LAN'     -     54
#   'CPS'     -     37
#   'LRP'     -    300
#   'LDN'     -     35
#   'ORN'     -     37
#   'BP'      -    521
#   'ERN'     -   1017
#   'Pe'      -    301
#   'CRN'     -     92
#   'MFN'     -     94
#   'SPeN'    -    122
#   'FRN'     -    574
#   'Pd'      -     22
#   'EDAN'    -     22
#   'LDAP'    -     15
#   'ADAN'    -     29
#   'EPN'     -    235
#   'SN'      -     76
#   'SP'      -     33
#   'SPN'     -     19
#   'SPCN'    -     41
#   'PCN'     -     62
#   'VsEP'    -    193
#   'MRPC'    -    297
#   'FSP'     -     20
#   'pN'      -     23
#   'LPN'     -     28
#   'LPP'     -     23
#   'EFN'     -     10
#   'FN400'   -    165
#   'PMN'     -     12
#   'VAN'     -     31

# %%
# Check how many papers were found for each association term
counts.check_counts(dim='B')
# Out:
# The number of documents found for each search term is:
#   'alcoholism'             -    50839
#   'addiction'              -    49547
#   'ADHD'                   -    33006
#   'alzheimer'              -   155621
#   'anxiety'                -   205584
#   'aphasia'                -    13975
#   'autism'                 -    47927
#   'bipolar'                -    65399
#   'coma'                   -    34598
#   'dementia'               -   116187
#   'depression'             -   363681
#   'dyslexia'               -     5684
#   'epilepsy'               -   145539
#   'migraine'               -    35518
#   'MCI'                    -    47488
#   'multiple sclerosis'     -    78811
#   'OCD'                    -    15485
#   'parkinson'              -   109015
#   'personality disorder'   -    15347
#   'PTSD'                   -    31096
#   'psychosis'              -    40084
#   'schizophrenia'          -   116769
#   'stroke'                 -   256822
#   'substance abuse'        -    25973
#   'TBI'                    -    43867

# %%
# Check the most commonly associated association term for each ERP
counts.check_data()
# Out:
# For  'P100'   the highest association is  'multiple sclerosis'    with         132
# For  'P150'   the highest association is  'anxiety'               with           5
# For  'P170'   the highest association is  'ADHD'                  with           1
# For  'P180'   the highest association is  'epilepsy'              with           5
# For  'P200'   the highest association is  'schizophrenia'         with          76
# For  'P220'   the highest association is  'stroke'                with           1
# For  'P230'   the highest association is  'alcoholism'            with           0
# For  'P240'   the highest association is  'dementia'              with           1
# For  'P250'   the highest association is  'ADHD'                  with           4
# For  'P270'   the highest association is  'alzheimer'             with           1
# For  'P300'   the highest association is  'schizophrenia'         with         472
# For  'P3a'    the highest association is  'schizophrenia'         with          92
# For  'P3b'    the highest association is  'schizophrenia'         with          58
# For  'P340'   the highest association is  'stroke'                with           3
# For  'P350'   the highest association is  'ADHD'                  with           4
# For  'P400'   the highest association is  'autism'                with          14
# For  'P500'   the highest association is  'ADHD'                  with           2
# For  'P550'   the highest association is  'epilepsy'              with           1
# For  'P600'   the highest association is  'schizophrenia'         with          12
# For  'N100'   the highest association is  'schizophrenia'         with         143
# For  'N110'   the highest association is  'addiction'             with           1
# For  'N120'   the highest association is  'depression'            with           5
# For  'N130'   the highest association is  'alzheimer'             with           2
# For  'N140'   the highest association is  'parkinson'             with           4
# For  'N150'   the highest association is  'epilepsy'              with           3
# For  'N160'   the highest association is  'schizophrenia'         with           4
# For  'N170'   the highest association is  'autism'                with          64
# For  'N180'   the highest association is  'schizophrenia'         with           2
# For  'N190'   the highest association is  'autism'                with           1
# For  'N200'   the highest association is  'schizophrenia'         with          40
# For  'N2a'    the highest association is  'alzheimer'             with          24
# For  'N2b'    the highest association is  'schizophrenia'         with          15
# For  'N2c'    the highest association is  'schizophrenia'         with           1
# For  'N2pc'   the highest association is  'anxiety'               with          20
# For  'N240'   the highest association is  'alzheimer'             with           1
# For  'N250'   the highest association is  'schizophrenia'         with          15
# For  'N270'   the highest association is  'MCI'                   with           4
# For  'N280'   the highest association is  'multiple sclerosis'    with           1
# For  'N290'   the highest association is  'autism'                with           8
# For  'N300'   the highest association is  'schizophrenia'         with           4
# For  'N320'   the highest association is  'dyslexia'              with           2
# For  'N350'   the highest association is  'TBI'                   with           2
# For  'N400'   the highest association is  'schizophrenia'         with         105
# For  'N450'   the highest association is  'depression'            with           9
# For  'N550'   the highest association is  'alcoholism'            with           4
# For  'N600'   the highest association is  'autism'                with           1
# For  'N700'   the highest association is  'autism'                with           1
# For  'MMN'    the highest association is  'schizophrenia'         with         483
# For  'LPC'    the highest association is  'schizophrenia'         with          17
# For  'LPP'    the highest association is  'anxiety'               with          97
# For  'NSW'    the highest association is  'schizophrenia'         with           5
# For  'PSW'    the highest association is  'anxiety'               with           3
# For  'VPP'    the highest association is  'depression'            with           5
# For  'CNV'    the highest association is  'migraine'              with          68
# For  'PINV'   the highest association is  'depression'            with           9
# For  'ELAN'   the highest association is  'aphasia'               with           1
# For  'LAN'    the highest association is  'alcoholism'            with           0
# For  'CPS'    the highest association is  'aphasia'               with           1
# For  'LRP'    the highest association is  'parkinson'             with          10
# For  'LDN'    the highest association is  'dyslexia'              with           7
# For  'ORN'    the highest association is  'autism'                with           3
# For  'BP'     the highest association is  'parkinson'             with          32
# For  'ERN'    the highest association is  'anxiety'               with         153
# For  'Pe'     the highest association is  'depression'            with          25
# For  'CRN'    the highest association is  'anxiety'               with          16
# For  'MFN'    the highest association is  'depression'            with           4
# For  'SPeN'   the highest association is  'anxiety'               with           6
# For  'FRN'    the highest association is  'anxiety'               with          31
# For  'Pd'     the highest association is  'ADHD'                  with           2
# For  'EDAN'   the highest association is  'autism'                with           1
# For  'LDAP'   the highest association is  'alcoholism'            with           0
# For  'ADAN'   the highest association is  'autism'                with           1
# For  'EPN'    the highest association is  'anxiety'               with          16
# For  'SN'     the highest association is  'ADHD'                  with           2
# For  'SP'     the highest association is  'ADHD'                  with           3
# For  'SPN'    the highest association is  'alcoholism'            with           0
# For  'SPCN'   the highest association is  'anxiety'               with           2
# For  'PCN'    the highest association is  'anxiety'               with           2
# For  'VsEP'   the highest association is  'multiple sclerosis'    with           5
# For  'MRPC'   the highest association is  'stroke'                with          39
# For  'FSP'    the highest association is  'ADHD'                  with           2
# For  'pN'     the highest association is  'MCI'                   with           1
# For  'LPN'    the highest association is  'autism'                with           1
# For  'LPP'    the highest association is  'coma'                  with           1
# For  'EFN'    the highest association is  'alcoholism'            with           0
# For  'FN400'  the highest association is  'schizophrenia'         with           5
# For  'PMN'    the highest association is  'aphasia'               with           1
# For  'VAN'    the highest association is  'schizophrenia'         with           1

# %%
# Check the most commonly associated ERP for each term
counts.check_data(dim='B')
# Out:
# For  'alcoholism'            the highest association is  'P300'   with         143
# For  'addiction'             the highest association is  'P300'   with          43
# For  'ADHD'                  the highest association is  'P300'   with          98
# For  'alzheimer'             the highest association is  'P300'   with         176
# For  'anxiety'               the highest association is  'ERN'    with         153
# For  'aphasia'               the highest association is  'N400'   with          26
# For  'autism'                the highest association is  'N170'   with          64
# For  'bipolar'               the highest association is  'P300'   with          68
# For  'coma'                  the highest association is  'MMN'    with          53
# For  'dementia'              the highest association is  'P300'   with         205
# For  'depression'            the highest association is  'P300'   with         216
# For  'dyslexia'              the highest association is  'MMN'    with          67
# For  'epilepsy'              the highest association is  'P300'   with          90
# For  'migraine'              the highest association is  'CNV'    with          68
# For  'MCI'                   the highest association is  'P300'   with         110
# For  'multiple sclerosis'    the highest association is  'P100'   with         132
# For  'OCD'                   the highest association is  'ERN'    with          67
# For  'parkinson'             the highest association is  'P300'   with          94
# For  'personality disorder'  the highest association is  'P300'   with          35
# For  'PTSD'                  the highest association is  'P300'   with          31
# For  'psychosis'             the highest association is  'MMN'    with         117
# For  'schizophrenia'         the highest association is  'MMN'    with         483
# For  'stroke'                the highest association is  'P300'   with          66
# For  'substance abuse'       the highest association is  'P300'   with          18
# For  'TBI'                   the highest association is  'P300'   with          51

# %% [markdown]
# ## Select ERPs with enough articles

# %%
# Check how many ERPs currently
counts.terms['A'].n_terms
# Out:
# 88

# %%
# Drop ERPs without a target number of articles
counts.drop_data(150, dim='A')
print(counts.terms['A'].n_terms)
# Out:
# 32

# %% [markdown]
# ## Group Level Plots

# %%
# Compute the normalized score (percent association)
counts.compute_score('normalize', dim='A')

# %%
# Plot the matrix of percent associations - ERPs & terms
plot_matrix(counts, figsize=(10, 8), 
            save_fig=SAVE_FIG, f_name=name+'_associations.pdf', directory=figs_dir)

# %% [markdown]
# ### Similarity Measure

# %%
# Calculate similarity between all ERPs (based on term association percents)
counts.compute_score('similarity')

# %%
# Plot similarity matrix between ERPs
plot_matrix(counts, figsize=(10, 6),
            save_fig=SAVE_FIG, f_name=name+'_similarity.pdf', directory=figs_dir)

# %%
# Plot a clustermap, clustering ERPs and terms based on similarity
plot_clustermap(counts, cmap='blue', figsize=(12, 10),
                save_fig=SAVE_FIG, f_name=name+'_similarity_cluster.pdf', directory=figs_dir)

# %% [markdown]
# ### Association Score

# %%
# Calculate association between all ERPs
counts.compute_score('association')

# %%
# Plot similarity matrix between terms
plot_matrix(counts, figsize=(10, 7),
            save_fig=SAVE_FIG, f_name=name+'_associations.pdf', directory=figs_dir)

# %% [markdown]
# ### Dendrograms

# %%
# Plot dendrogram of ERPs, based on percent associations with terms
plot_dendrogram(counts, attribute='score', figsize=(6, 8),
                save_fig=SAVE_FIG, f_name=name+'_erp_dendro.pdf', directory=figs_dir)

# %%
# Plot dendrogram of termss, based on percent associations with ERPs
plot_dendrogram(counts, attribute='score', transpose=True, figsize=(6, 8),
                save_fig=SAVE_FIG, f_name=name+'term_dendro.pdf', directory=figs_dir)

# %% [markdown]
# ### Function correlates across time

# %%
# Re-compute normalized score
counts.compute_score('normalize')

# %%
# Get the time and polarity information for the ERPs
time_associations = get_time_associations(counts)

# %%
# Plot time associations
plot_time_associations(time_associations,
                       save_fig=SAVE_FIG, f_name=name+'time.pdf', directory=figs_dir)
